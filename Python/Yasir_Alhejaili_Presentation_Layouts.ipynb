# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none; background-color: #ffffff">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>05. Presentation and Layout</h2></div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# In the previous chapters we started to learn how to create single plots using differnet kinds of data. But we often want to plot more than one thing. Boeh plots can be individually embedded in HTML documents, but it's often easier to
# combine multiple plots in one of Bokeh's built-in layouts. We will learn how to do that in this chapter
#
# The cell below defines a few data variables we will use in examples.

# %%
x = list(range(11))
y0, y1, y2 = x, [10-i for i in x], [abs(i-5) for i in x]

# %% [markdown]
# # Rows and Columns
# The `bokeh.layouts` modules provides the ``row`` and ``column`` functions to arrange plot objects in vertical or horizontal layouts. Below is an example of three plots arranged in a row.

# %%
from bokeh.layouts import row

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# show the results in a row
show(row(s1, s2, s3))
# Out:
#   <div class="bk-root" id="c57cd6d6-fa44-42cb-b179-5d587a5be4ab" data-root-id="1110"></div>

# %%
# EXERCISE: use column to arrange a few plots vertically
from bokeh.layouts import column

# create a new plot
k1 = figure(width=250, plot_height=250 , title = "1 plot")
k1.hex(x, y0, size=10, color="navy", alpha=0.5)
k1.background_fill_color = "beige"
k1.background_fill_alpha = 0.5

# create another one
k2 = figure(width=250, height=250 , title = "2 plot")
k2.triangle(x, y1, size=10, color="firebrick", alpha=0.8)
k2.background_fill_color = "powderblue"
k2.background_fill_alpha = 0.5

# create and another
k3 = figure(width=250, height=250 , title = "3 plot")
k3.x(x, y2, size=10, color="black")
k3.background_fill_color = "darkcyan"
k3.background_fill_alpha = 0.5

# show the results in a row
show(column(k1, k2, k3))
# Out:
#   <div class="bk-root" id="515c7016-967e-46c5-b391-8aec8058b06f" data-root-id="62632"></div>

# %% [markdown]
# # Grid plots
#
# Bokeh also provides a `gridplot` layout in `bokeh.layouts` for arranging plots in a grid, as show in the example below.

# %%
from bokeh.layouts import gridplot

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# put all the plots in a gridplot
p = gridplot([[s1, s2], [s3, None]], toolbar_location=None)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="027b7b29-12b1-4c50-8b23-9f4df16d6306" data-root-id="6498"></div>

# %%
# EXERCISE: create a gridplot of your own
z = list(range(11))
w0, w1, w2 = z, [10-i for i in z], [abs(i-5) for i in z]
w3 = [1,1.5,2,2,2,2.5,3,3.5,4,4]


# 1 plot
p1 = figure(width=250, plot_height=250 , title = "1 plot")
p1.hex(z, w0, size=10, color="navy", alpha=0.5)
p1.background_fill_color = "beige"
p1.background_fill_alpha = 0.5

# 2 plot
p2 = figure(width=250, height=250 , title = "2 plot")
p2.triangle(z, w1, size=10, color="firebrick", alpha=0.5)
p2.background_fill_color = "powderblue"
p2.background_fill_alpha = 0.5

# 3 plot
p3 = figure(width=250, height=250 , title = "3 plot")
p3.circle(z, w2, size=10, color="black", alpha=0.7)
p3.background_fill_color = "darkcyan"
p3.background_fill_alpha = 0.5

# 4 plot
p4 = figure(width=250, height=250 , title = "4 plot")
p4.x(z, w3, size=10, color="green")
p4.background_fill_color = "blanchedalmond"
p4.background_fill_alpha = 0.5
# put all the plots in a gridplot
p = gridplot([[p1, p2], [p3, p4]])

# show the results
show(p)
# Out:
# ...
#   <div class="bk-root" id="78b56ca3-743a-4e79-a122-75ea1fa468d0" data-root-id="51802"></div>
